# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# ## Covid 19 Project

# %%
#importing the dataset
df = pd.read_csv(R"C:\Users\moham\OneDrive\Desktop\Excel NTI PROJECRS\Covid project\owid-covid-data.csv")
df.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-01-03          NaN        0.0
# 1      AFG      Asia  Afghanistan  2020-01-04          NaN        0.0
# 2      AFG      Asia  Afghanistan  2020-01-05          NaN        0.0
# 3      AFG      Asia  Afghanistan  2020-01-06          NaN        0.0
# 4      AFG      Asia  Afghanistan  2020-01-07          NaN        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         0.0                  NaN  ...
# 1                 NaN           NaN         0.0                  NaN  ...
# 2                 NaN           NaN         0.0                  NaN  ...
# 3                 NaN           NaN         0.0                  NaN  ...
# 4                 NaN           NaN         0.0                  NaN  ...
#
#    male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# ...

# %%
#Expolre the dataset's columns
df.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'total_tests', 'new_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
# ...

# %%
df.shape
# Out:
# (344779, 67)

# %%
df.location.unique()
# Out:
# array(['Afghanistan', 'Africa', 'Albania', 'Algeria', 'American Samoa',
#        'Andorra', 'Angola', 'Anguilla', 'Antigua and Barbuda',
#        'Argentina', 'Armenia', 'Aruba', 'Asia', 'Australia', 'Austria',
#        'Azerbaijan', 'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados',
#        'Belarus', 'Belgium', 'Belize', 'Benin', 'Bermuda', 'Bhutan',
#        'Bolivia', 'Bonaire Sint Eustatius and Saba',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei', 'Bulgaria', 'Burkina Faso',
#        'Burundi', 'Cambodia', 'Cameroon', 'Canada', 'Cape Verde',
#        'Cayman Islands', 'Central African Republic', 'Chad', 'Chile',
#        'China', 'Colombia', 'Comoros', 'Congo', 'Cook Islands',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Curacao',
#        'Cyprus', 'Czechia', 'Democratic Republic of Congo', 'Denmark',
#        'Djibouti', 'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt',
# ...

# %%
df_world = df[df.location == 'World']
df_world.head(5)
# Out:
#         iso_code continent location        date  total_cases  new_cases  \
# 339322  OWID_WRL       NaN    World  2020-01-03          NaN        0.0
# 339323  OWID_WRL       NaN    World  2020-01-04          3.0        3.0
# 339324  OWID_WRL       NaN    World  2020-01-05          2.0        0.0
# 339325  OWID_WRL       NaN    World  2020-01-06          5.0        3.0
# 339326  OWID_WRL       NaN    World  2020-01-07          5.0        0.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 339322                 NaN           NaN         0.0                  NaN
# 339323                 NaN           NaN         0.0                  NaN
# 339324                 NaN           3.0         3.0                  NaN
# 339325                 NaN           3.0         0.0                  NaN
# 339326                 NaN           3.0         0.0                  NaN
#
#         ...  male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# ...

# %%
#find the highest number of new deaths in male smokers
df_world[df_world['new_deaths'] == df_world['new_deaths'].max()]['male_smokers']
# Out:
# 339709    34.635
# Name: male_smokers, dtype: float64

# %%
#find the highest number of new deaths in female smokers
df_world[df_world['new_deaths'] == df_world['new_deaths'].max()]['female_smokers']
# Out:
# 339709    6.434
# Name: female_smokers, dtype: float64

# %%
#find the date with the highest number of new deaths
df_world[df_world['new_deaths'] == df_world['new_deaths'].max()]['date']
# Out:
# 339709    2021-01-24
# Name: date, dtype: object

# %%
df_world_recent = df_world.tail(1)
df_world_recent
# Out:
#         iso_code continent location        date  total_cases  new_cases  \
# 340686  OWID_WRL       NaN    World  2023-09-28          NaN        NaN
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 340686                 NaN           NaN         NaN                  NaN
#
#         ...  male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 340686  ...        34.635                   60.13                       2.705
#
#         life_expectancy  human_development_index    population  \
# 340686            72.58                    0.737  7.975105e+09
#
#         excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 340686                                   NaN                          NaN
#
#         excess_mortality  excess_mortality_cumulative_per_million
# 340686               NaN                                      NaN
#
# [1 rows x 67 columns]

# %%
#find the total cases, new cases, new deaths and total deaths in recent date
df_world_recent.groupby("date")[["total_cases","new_cases","new_deaths","total_deaths"]].sum()
# Out:
#             total_cases  new_cases  new_deaths  total_deaths
# date
# 2023-09-28          0.0        0.0         0.0           0.0

# %%
#The highst number of population
df_world.population.max()
# Out:
# np.float64(7975105024.0)

# %%
#The lowest number of population
df_world.population.min()
# Out:
# np.float64(7975105024.0)

# %%
#The average number of population
df_world.population.mean()
# Out:
# np.float64(7975105024.0)

# %%
#The highest number of total cases
df_world['total_cases'].max()
# Out:
# np.float64(770874669.0)

# %%
#The lowest number of total cases
df_world['total_cases'].min()
# Out:
# np.float64(2.0)

# %%
#the average number of total cases
df_world['total_cases'].mean().__round__()
# Out:
# 349262651

# %%
#The World ratio
df_world_ratio = df_world['total_cases'].max() / df_world['population'].max().round(2)
df_world_ratio
# Out:
# np.float64(0.09666012756949996)

# %%
#The highest number of total deaths per million
highest_deaths_per_million = df.groupby('location')['total_deaths_per_million'].max().idxmax()
print("Country with highest deaths per million:", highest_deaths_per_million)
# Out:
# Country with highest deaths per million: Peru

# %%
#the lowest number of total deaths per million
highest_deaths_per_million = df.groupby('location')['total_deaths_per_million'].min().idxmax()
print("Country with highest deaths per million:", highest_deaths_per_million)
# Out:
# Country with highest deaths per million: Wallis and Futuna

# %%
#highest number of Continent deaths
continent_deaths = df.groupby('continent')['total_deaths'].max().dropna().sort_values(ascending=False)
continent_deaths
# Out:
# continent
# North America    1127152.0
# South America     704659.0
# Asia              532031.0
# Europe            400023.0
# Africa            102595.0
# Oceania            23601.0
# Name: total_deaths, dtype: float64

# %%
location_deaths_max = df.groupby('location')['total_deaths'].max().dropna().sort_values(ascending=False)
location_deaths_max.head(8)
# Out:
# location
# World                  6959303.0
# High income            2902099.0
# Upper middle income    2666236.0
# Europe                 2077076.0
# Asia                   1633643.0
# North America          1603080.0
# South America          1356205.0
# Lower middle income    1339026.0
# Name: total_deaths, dtype: float64

# %%
location_deaths_min = df.groupby('location')['total_deaths'].min().dropna().sort_values(ascending=False)
location_deaths_min.head(6)
# Out:
# location
# Ghana                           301.0
# Democratic Republic of Congo    209.0
# Mauritania                      149.0
# Senegal                         137.0
# Gambia                          113.0
# Estonia                          73.0
# Name: total_deaths, dtype: float64

# %%
world_population = df['population'].sum()
fully_vaccinated = df['people_fully_vaccinated'].sum()
vaccination_percentage = (fully_vaccinated / world_population) * 100
print(f"World vaccination: {vaccination_percentage:.2f}%")
# Out:
# World vaccination: 28.68%

# %%
df_egypt = df[df['location'] == 'Egypt']
df_egypt.head()
# Out:
#       iso_code continent location        date  total_cases  new_cases  \
# 84573      EGY    Africa    Egypt  2020-01-03          NaN        0.0
# 84574      EGY    Africa    Egypt  2020-01-04          NaN        0.0
# 84575      EGY    Africa    Egypt  2020-01-05          NaN        0.0
# 84576      EGY    Africa    Egypt  2020-01-06          NaN        0.0
# 84577      EGY    Africa    Egypt  2020-01-07          NaN        0.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 84573                 NaN           NaN         0.0                  NaN  ...
# 84574                 NaN           NaN         0.0                  NaN  ...
# 84575                 NaN           NaN         0.0                  NaN  ...
# 84576                 NaN           NaN         0.0                  NaN  ...
# 84577                 NaN           NaN         0.0                  NaN  ...
#
#        male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# ...

# %%
egy_population = df_egypt['population'].sum()
egy_fully_vaccinated = df_egypt['people_fully_vaccinated'].sum()
egy_vaccination_percentage = (egy_fully_vaccinated / egy_population) * 100
print(f"Egypt vaccination: {egy_vaccination_percentage:.2f}%")
# Out:
# Egypt vaccination: 1.52%

# %%
df_world_over_time = df_world.groupby(["date"])[["total_cases","new_cases","total_deaths","new_deaths"]].sum().reset_index().sort_values("date",ascending=True).reset_index(drop=True)
df_world_over_time
# Out:
#             date  total_cases  new_cases  total_deaths  new_deaths
# 0     2020-01-03          0.0        0.0           0.0         0.0
# 1     2020-01-04          3.0        3.0           0.0         0.0
# 2     2020-01-05          2.0        0.0           3.0         3.0
# 3     2020-01-06          5.0        3.0           3.0         0.0
# 4     2020-01-07          5.0        0.0           3.0         0.0
# ...          ...          ...        ...           ...         ...
# 1360  2023-09-24  770874669.0     1060.0     6959303.0        22.0
# 1361  2023-09-25  770874669.0        0.0     6959303.0         0.0
# 1362  2023-09-26  770874669.0        0.0     6959303.0         0.0
# 1363  2023-09-27  770874669.0        0.0     6959303.0         0.0
# 1364  2023-09-28          0.0        0.0           0.0         0.0
#
# [1365 rows x 5 columns]

# %%
# Select numerical columns for correlation
numeric_cols = [
    'total_cases', 'new_cases', 'total_deaths', 'new_deaths',
    'total_cases_per_million', 'total_deaths_per_million',
    'people_fully_vaccinated_per_hundred', 'population_density',
    'gdp_per_capita', 'median_age'
]
corr_df = df[numeric_cols].corr()
# Plot the heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(corr_df, annot=True, cmap="coolwarm", center=0, fmt=".2f")
plt.title("COVID-19 Data Correlation Heatmap")
plt.show()

# %%
plt.figure(figsize=(10, 6))   
sns.histplot(x='median_age', data=df, bins=50, kde=True) 
plt.title('Distr. of Median Age in Dataset', fontsize=14)
plt.xlabel('Median Age', fontsize=14)
plt.ylabel('Frequency', fontsize=14)
plt.show()

# %%
plt.figure(figsize=(10, 6))  

sns.scatterplot(x='new_cases', y='new_deaths',hue='male_smokers', data=df, palette='viridis',size_order= 30)

plt.title('Relation between new cases and new deaths', fontsize=14)
plt.xlabel('new cases', fontsize=14)
plt.ylabel('new deaths', fontsize=14)
plt.legend(loc='upper right')

plt.show()

# %%
latest_data = df.drop_duplicates(subset=['location'], keep='last')

# Select relevant columns and drop missing values
plot_data = latest_data.dropna(subset=['gdp_per_capita', 'hospital_beds_per_thousand'])

# Plot the scatter plot
plt.figure(figsize=(10, 6))
sns.scatterplot(x='gdp_per_capita', y='hospital_beds_per_thousand', data=plot_data, hue='extreme_poverty',palette='viridis')
plt.title('GDP per Capita vs. Hospital Beds per Thousand', fontsize=14)
plt.xlabel('GDP per Capita', fontsize=12)
plt.ylabel('Hospital Beds per Thousand', fontsize=12)
plt.show()

# %%
df_world_over_time = df_world.groupby(["date"])[["total_cases","new_cases","total_deaths","new_deaths"]].sum().reset_index()
df_world_over_time
# Out:
#             date  total_cases  new_cases  total_deaths  new_deaths
# 0     2020-01-03          0.0        0.0           0.0         0.0
# 1     2020-01-04          3.0        3.0           0.0         0.0
# 2     2020-01-05          2.0        0.0           3.0         3.0
# 3     2020-01-06          5.0        3.0           3.0         0.0
# 4     2020-01-07          5.0        0.0           3.0         0.0
# ...          ...          ...        ...           ...         ...
# 1360  2023-09-24  770874669.0     1060.0     6959303.0        22.0
# 1361  2023-09-25  770874669.0        0.0     6959303.0         0.0
# 1362  2023-09-26  770874669.0        0.0     6959303.0         0.0
# 1363  2023-09-27  770874669.0        0.0     6959303.0         0.0
# 1364  2023-09-28          0.0        0.0           0.0         0.0
#
# [1365 rows x 5 columns]

# %%
plt.figure(figsize=(20, 10))
plt.plot(df_world['date'], 
         df_world['total_cases'], 
         color='#1f77b4', 
         linewidth=2.5,
         alpha=1,
         label='Total Cases')
plt.xlabel('Date', fontsize=14)
plt.ylabel('Total Cases', fontsize=14)
plt.title('World', fontsize=14)
# Out:
# Text(0.5, 1.0, 'World')

# %%
plt.figure(figsize=(20,10))
plt.plot(df_egypt['date'], 
         df_egypt['total_cases'], 
         color='#1f77b4', 
         linewidth=2.5,
         alpha=1,
         label='Total Cases')
plt.xlabel('Date', fontsize=14)
plt.ylabel('Total Cases', fontsize=14)
plt.title('Egypt', fontsize=14)
# Out:
# Text(0.5, 1.0, 'Egypt')

# %%
df['date'] = pd.to_datetime(df['date'])
vax_progress = df.groupby(['date', 'continent'])['people_fully_vaccinated_per_hundred'].mean().unstack()
vax_progress.plot.area(stacked=False, figsize=(12, 6))
plt.title("Global Vaccination Progress by Continent")
plt.show()

# %%
df.sample(5)
# Out:
#         iso_code      continent          location       date  total_cases  \
# 289736       SSD         Africa       South Sudan 2021-12-06      12823.0
# 226155  OWID_NIR         Europe  Northern Ireland 2023-03-11          NaN
# 83834        ECU  South America           Ecuador 2021-09-19     506539.0
# 47087        BFA         Africa      Burkina Faso 2021-12-10      16334.0
# 240582       PER  South America              Peru 2021-08-13    2128516.0
#
#         new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 289736        4.0               9.714         133.0         0.0
# 226155        NaN                 NaN           NaN         NaN
# 83834       454.0             209.143       32634.0        42.0
# 47087         0.0              47.714         290.0         0.0
# 240582     1482.0            1349.714      197146.0        44.0
#
#         new_deaths_smoothed  ...  male_smokers  handwashing_facilities  \
# ...

# %%
df_peru = df[df['location'] == 'Peru']
df_peru.head(3)
# Out:
#        iso_code      continent location       date  total_cases  new_cases  \
# 239994      PER  South America     Peru 2020-01-03          NaN        0.0
# 239995      PER  South America     Peru 2020-01-04          NaN        0.0
# 239996      PER  South America     Peru 2020-01-05          NaN        0.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 239994                 NaN           NaN         0.0                  NaN
# 239995                 NaN           NaN         0.0                  NaN
# 239996                 NaN           NaN         0.0                  NaN
#
#         ...  male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 239994  ...           NaN                     NaN                         1.6
# 239995  ...           NaN                     NaN                         1.6
# 239996  ...           NaN                     NaN                         1.6
#
# ...

# %%
df_peru['total_deaths'].mean().__round__()
# Out:
# 165258

# %%
df_peru['new_deaths'].mean().__round__()
# Out:
# 162

# %%
df_peru['total_cases'].mean().__round__()
# Out:
# 2617266

# %%
df_peru['new_deaths'].max().__round__()
# Out:
# 843

# %%
df_peru['total_cases'].max().__round__()
# Out:
# 4519052

# %%
df_peru.sample(10)
# Out:
#        iso_code      continent location       date  total_cases  new_cases  \
# 240649      PER  South America     Peru 2021-10-19    2190009.0      844.0
# 241239      PER  South America     Peru 2023-06-01    4508103.0        0.0
# 240484      PER  South America     Peru 2021-05-07    1824457.0     5768.0
# 240050      PER  South America     Peru 2020-02-28          NaN        0.0
# 240597      PER  South America     Peru 2021-08-28    2146169.0     1118.0
# 241087      PER  South America     Peru 2022-12-31    4454236.0     3162.0
# 240570      PER  South America     Peru 2021-08-01    2109294.0      699.0
# 240108      PER  South America     Peru 2020-04-26      21648.0      734.0
# 240272      PER  South America     Peru 2020-10-07     829999.0     1830.0
# 240737      PER  South America     Peru 2022-01-15    2473709.0    33360.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# ...

# %%
# Group data by country and select the maximum values for each country (total cases and total deaths)
df_top = df.groupby('location')[['total_cases', 'total_deaths']].max()

# Select the top 10 countries with the highest number of cases and deaths
top_cases = df_top.nlargest(10, 'total_cases')  # Top 10 by total cases
top_deaths = df_top.nlargest(10, 'total_deaths')  # Top 10 by total deaths

# Convert values to millions for better readability
top_cases['total_cases'] /= 1e6
top_deaths['total_deaths'] /= 1e6

# Create a figure with two subplots side by side
fig, axes = plt.subplots(1, 2, figsize=(15, 6))

# Plot total cases (left subplot)
top_cases['total_cases'].plot(kind='barh', ax=axes[0], color='blue', edgecolor='black')
axes[0].set_title("Top 10 Countries by Total COVID-19 Cases")  # Chart title
axes[0].set_xlabel("Total Cases (Millions)")  # X-axis label
axes[0].invert_yaxis()  # Invert Y-axis to show country with highest cases at top

# Plot total deaths (right subplot)
top_deaths['total_deaths'].plot(kind='barh', ax=axes[1], color='red', edgecolor='black')
axes[1].set_title("Top 10 Countries by Total COVID-19 Deaths")  # Chart title
axes[1].set_xlabel("Total Deaths (Millions)")  # X-axis label
axes[1].invert_yaxis() 

# Format x-axis labels with one decimal place
for ax in axes:
    ax.xaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f'{x:,.1f}'))

# Adjust layout and display the plot
plt.tight_layout()
plt.show()

# %%
data2 = df.copy()
data2.date = pd.to_datetime(data2['date'])
data2 = data2.groupby('date').sum()
data2['7 days MA new cases'] = 0
data2['7 days MA new cases'] = data2['new_cases'].rolling(7).mean() #Moving average of new cases with window=10
data2['7 days MA new deaths'] = 0
data2['7 days MA new deaths'] = data2['new_deaths'].rolling(7).mean()  #Moving average of new deaths with window=10

data2[['new_cases', '7 days MA new cases']].plot(figsize = (11, 5), alpha = 0.5)
plt.title('Timeline new cases in world')
plt.xlabel('Date')
plt.ylabel('New cases')
# Out:
# Text(0, 0.5, 'New cases')

# %%
New_pl_data=df.groupby("date")[['total_cases','new_cases','new_cases_smoothed','total_deaths','new_deaths','new_deaths_smoothed','total_tests','new_tests','total_vaccinations','population_density','median_age','aged_65_older','aged_70_older']].sum().reset_index()
New_pl_data.head(5)
# Out:
#         date  total_cases  new_cases  new_cases_smoothed  total_deaths  \
# 0 2020-01-01          0.0        0.0                 0.0           0.0
# 1 2020-01-02          0.0        0.0                 0.0           0.0
# 2 2020-01-03          0.0        0.0                 0.0           0.0
# 3 2020-01-04         14.0       14.0                 0.0           0.0
# 4 2020-01-05          9.0        0.0                 0.0          15.0
#
#    new_deaths  new_deaths_smoothed  total_tests  new_tests  \
# 0         0.0                  0.0         29.0       29.0
# 1         0.0                  0.0        196.0      167.0
# 2         0.0                  0.0        290.0       94.0
# 3         0.0                  0.0        413.0      123.0
# 4        15.0                  0.0        510.0       97.0
#
#    total_vaccinations  population_density  median_age  aged_65_older  \
# 0                 0.0              82.621        61.2         18.055
# ...

# %%
g=[New_pl_data['total_cases'].max(),New_pl_data['total_tests'].max(),New_pl_data['total_deaths'].max(),New_pl_data['total_vaccinations'].max()]
mylabels = ["total_cases", "total_deaths", "total_tests", "total_vaccinations"]
myexplode = [0.2, 0.1 , 0.2, 0.1]
mycolors = ["g", "y", "b", "r"]

plt.pie(g, labels = mylabels, explode = myexplode ,colors = mycolors, startangle = 180 , autopct= '%1.1f%%' ,shadow = True)
plt.legend(title = "Names:",loc='upper left')
plt.show()

# %%
g=[New_pl_data['median_age'].max(),New_pl_data['aged_65_older'].max(),New_pl_data['aged_70_older'].max()]
mylabels = ["median_age", "aged_65_older", "aged_70_older"]
myexplode = [0.1, 0.1 , 0.1]
mycolors = ["g", "y", "b"]

plt.pie(g, labels = mylabels, explode = myexplode ,colors = mycolors, startangle = 45 , autopct= '%1.1f%%' ,shadow = True)
plt.legend(title = "Names:",loc='upper left')
plt.show()
